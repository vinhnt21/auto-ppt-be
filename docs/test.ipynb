# %% [markdown]
# # Flow
#  - Get the content of the document
#  - Generate:
#    - The topic of slides
#    - The outline of the document
#    - The slides of the document
#    - The summary of the document
#    - The thank you slide of the document

# %%
from ai.ai_response import get_slide_content, get_img_description_for_slide_url

# %%
from utils.extract_docx import *

content = extract_content_from_docx("uploads/I.docx")
slide = get_slide_content(content)
with open("slide_content.md", "w") as f:
    f.write(slide)
    f.close()

# %%
with open("slide_content.md", "r") as f:
    slides_str = f.read()
    f.close()
slides = slides_str.split("## ")[1:]

print(slides[3])
img_url = get_img_description_for_slide_url(slides[3], slides_str)
img_url
# Out:
# Lý do chọn đề tài
# - Lịch sử phản chiếu lòng yêu nước và sự hy sinh của dân tộc Việt Nam.
# - Kháng chiến chống Pháp và chống Mỹ là những mốc son quan trọng.
# - Cần cách tiếp cận sinh động để giới trẻ tìm hiểu lịch sử.
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-1P1bqZ32dNYdX0gPyUAEfcbm/user-Z35cxaCCxTlbpN2ZcbX4wq7f/img-fZBzTENGO42wSsi4e3DJ2AVE.png?st=2024-12-25T02%3A28%3A44Z&se=2024-12-25T04%3A28%3A44Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-12-24T18%3A44%3A21Z&ske=2024-12-25T18%3A44%3A21Z&sks=b&skv=2024-08-04&sig=C5dINFBrl5xlOsjkqxI1RCR7ttjd7Ra2nTOXlMxbptU%3D'

# %%
from openai import OpenAI
from config import OPENAI_API_KEY

client = OpenAI(api_key=OPENAI_API_KEY)

response = client.images.generate(
    model="dall-e-3",
    prompt="a white siamese cat",
    size="1024x1024",
    quality="standard",
    style="natural",
    n=1,
)

print(response.data[0].url)

# %%
# from pptx import Presentation
# from pptx.util import Inches, Pt
# from pptx.enum.text import PP_ALIGN
# from pptx.dml.color import RGBColor
# import markdown2
# from bs4 import BeautifulSoup
# import requests
# from io import BytesIO


# def hex_to_rgb(hex_color):
#     hex_color = hex_color.lstrip("#")
#     return tuple(int(hex_color[i : i + 2], 16) for i in (0, 2, 4))


# def set_slide_dimensions_16_9(prs):
#     """Set slide dimensions to 16:9 aspect ratio"""
#     prs.slide_width = Inches(16)
#     prs.slide_height = Inches(9)


# def apply_text_style(paragraph, font_name, font_size, font_color):
#     """Apply consistent text styling to a paragraph"""
#     paragraph.font.name = font_name
#     paragraph.font.size = Pt(font_size)
#     if font_color:
#         paragraph.font.color.rgb = RGBColor(*hex_to_rgb(font_color))


# def add_content_to_placeholder(placeholder, content, theme):
#     """Add content to a placeholder while maintaining styling"""
#     text_frame = placeholder.text_frame
#     text_frame.clear()

#     if isinstance(content, str):
#         p = text_frame.add_paragraph()
#         p.text = content
#         apply_text_style(p, theme["FONT"], 24, theme["CONTENT_COLOR"])
#     elif isinstance(content, list):
#         for item in content:
#             p = text_frame.add_paragraph()
#             p.text = f"• {item}" if item.strip() else ""
#             apply_text_style(p, theme["FONT"], 24, theme["CONTENT_COLOR"])
#             p.line_spacing = 1.2


# def get_image_stream(img_src):
#     """Get image stream from URL or local path"""
#     try:
#         if img_src.startswith(("http://", "https://")):
#             response = requests.get(img_src)
#             return BytesIO(response.content)
#         return img_src
#     except Exception as e:
#         print(f"Error processing image {img_src}: {e}")
#         return None


# def markdown_to_pptx(
#     markdown_content, output_file, template_path=None, custom_theme=None
# ):
#     # Default theme
#     default_theme = {
#         "FONT": "Arial",
#         "TITLE_COLOR": "#083B4A",
#         "CONTENT_COLOR": "#000000",
#         "BG_COLOR": "#D3D3D3",
#     }
#     theme = default_theme if custom_theme is None else {**default_theme, **custom_theme}

#     # Create presentation
#     prs = Presentation(template_path) if template_path else Presentation()
#     set_slide_dimensions_16_9(prs)

#     # Convert markdown to HTML
#     html_content = markdown2.markdown(markdown_content)
#     soup = BeautifulSoup(html_content, "html.parser")

#     # Split content into slides
#     slides = []
#     current_slide = []
#     for element in soup.find_all(["h2", "ul", "img"]):
#         if element.name == "h2" and current_slide:
#             slides.append(current_slide)
#             current_slide = []
#         current_slide.append(element)
#     if current_slide:
#         slides.append(current_slide)

#     # Process slides
#     for i, slide_content in enumerate(slides):
#         title_text = slide_content[0].text
#         content_elements = slide_content[1:] if len(slide_content) > 1 else []

#         if i == 0:  # Title slide
#             slide = prs.slides.add_slide(prs.slide_layouts[0])
#             title = slide.shapes.title
#             subtitle = slide.placeholders[1]

#             title.text = title_text
#             apply_text_style(
#                 title.text_frame.paragraphs[0], theme["FONT"], 44, theme["TITLE_COLOR"]
#             )

#             if content_elements and content_elements[0].name == "ul":
#                 subtitle_text = content_elements[0].find("li").text
#                 subtitle.text = subtitle_text
#                 apply_text_style(
#                     subtitle.text_frame.paragraphs[0],
#                     theme["FONT"],
#                     28,
#                     theme["CONTENT_COLOR"],
#                 )

#         elif i == len(slides) - 1:  # Last slide
#             slide = prs.slides.add_slide(prs.slide_layouts[5])
#             title = slide.shapes.title
#             title.text = title_text
#             paragraph = title.text_frame.paragraphs[0]
#             paragraph.alignment = PP_ALIGN.CENTER
#             apply_text_style(paragraph, theme["FONT"], 44, theme["TITLE_COLOR"])

#         else:  # Content slides
#             has_image = any(element.name == "img" for element in content_elements)
#             has_text = any(element.name == "ul" for element in content_elements)

#             if has_image and has_text:
#                 slide = prs.slides.add_slide(prs.slide_layouts[3])  # Two Content
#             else:
#                 slide = prs.slides.add_slide(prs.slide_layouts[1])  # Title and Content

#             # Add title
#             title = slide.shapes.title
#             title.text = title_text
#             apply_text_style(
#                 title.text_frame.paragraphs[0], theme["FONT"], 36, theme["TITLE_COLOR"]
#             )

#             # Track if we've used the first content placeholder
#             first_content_used = False

#             for element in content_elements:
#                 if element.name == "ul":
#                     # Find an available content placeholder
#                     for shape in slide.placeholders:
#                         if (
#                             shape.placeholder_format.idx in (1, 2)
#                             and not first_content_used
#                         ):
#                             bullet_points = [li.text for li in element.find_all("li")]
#                             add_content_to_placeholder(shape, bullet_points, theme)
#                             first_content_used = True
#                             break

#                 elif element.name == "img":
#                     img_src = element.get("src")
#                     if img_src:
#                         image_stream = get_image_stream(img_src)
#                         if image_stream:
#                             # Try to find a picture placeholder
#                             picture_placeholder = None
#                             for shape in slide.placeholders:
#                                 if (
#                                     not first_content_used
#                                     and shape.placeholder_format.idx in (1, 2, 18)
#                                 ):
#                                     picture_placeholder = shape
#                                     break

#                             try:
#                                 if picture_placeholder:
#                                     picture_placeholder.insert_picture(image_stream)
#                                     first_content_used = True
#                                 else:
#                                     # If no placeholder available, add picture directly
#                                     left = (
#                                         Inches(8.5) if first_content_used else Inches(1)
#                                     )
#                                     slide.shapes.add_picture(
#                                         image_stream,
#                                         left=left,
#                                         top=Inches(2.5),
#                                         width=Inches(6.5),
#                                     )
#                             except Exception as e:
#                                 print(f"Error adding image: {e}")

#     prs.save(output_file)
#     print(f"Created PowerPoint file: {output_file}")


# with open("test.md", "r") as f:
#     content = f.read()
# markdown_to_pptx(content, "test.pptx")
# Out:
# Error adding image: cannot identify image file <_io.BytesIO object at 0x00000225AEB20F40>
# Created PowerPoint file: test.pptx
